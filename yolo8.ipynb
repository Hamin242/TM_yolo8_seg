# %% [raw]
# ## https://docs.ultralytics.com/tasks/segment/#export
# ## https://docs.ultralytics.com/models/sam/#sam-prediction-example
# ## https://www.kaggle.com/code/stpeteishii/flickr-yolov8-object-detection-segmentation/notebook

# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import os
import numpy as np
import pandas as pd
from PIL import Image
import cv2
import matplotlib.pyplot as plt


# Load a model
model = YOLO("yolov8n.pt")       # for detection
model2 = YOLO("yolov8n-seg.pt")  # for segmentation
model3 = YOLO("yolov8n-cls.pt")  # for classification
# Out:
# ...
#   0%|          | 0.00/5.28M [00:00<?, ?B/s]

# %%
path0='D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/train'
paths0=[]
for dirname, _, filenames in os.walk(path0):
    for filename in filenames:
        if filename[-4:]=='.jpg':
            paths0+=[(os.path.join(dirname, filename))]

# %%
import shutil
for path in paths0[36:40]:
    print(path)
    file=path.split('\\')[-1]
#     print('D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/'+file)
    shutil.copy(path,'D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/'+file)
# Out:
# D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/train\20220905_134848_200000_15.jpg
# D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/train\20220905_135207_185714_0.jpg
# D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/train\20220905_135508_178571_8.jpg
# D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/train\20220905_135840_36905_21.jpg

# %%
paths1=[]
for dirname, _, filenames in os.walk('D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/'):
    for filename in filenames:
        if filename[-4:]=='.jpg':
            paths1+=[(os.path.join(dirname, filename))]

# %%
paths1
# Out:
# ['D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/20220905_134848_200000_15.jpg',
#  'D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/20220905_135207_185714_0.jpg',
#  'D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/20220905_135508_178571_8.jpg',
#  'D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/20220905_135840_36905_21.jpg']

# %%
image = Image.open(paths1[0])
image=np.array(image)
plt.figure(figsize=(20,10))
plt.imshow(image)
plt.show()

# %%
results = model.predict(paths1[0],conf=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 results = model.predict(paths1[0],conf=0.5)
#
# File C:\Programs\Python\Python310\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File C:\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\engine\model.py:249, in YOLO.predict(self, source, stream, **kwargs)
#     247 if not self.predictor:
#     248     self.task = overrides.get('task') or self.task
# --> 249     self.predictor = TASK_MAP[self.task][3](overrides=overrides, _callbacks=self.callbacks)
#     250     self.predictor.setup_model(model=self.model, verbose=is_cli)
# ...

# %%
image = Image.open(paths1[0])
image = np.asarray(image)
plot_bboxes(image, results[0].boxes.boxes, score=True, conf=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 3>()
#       1 image = Image.open(paths1[0])
#       2 image = np.asarray(image)
# ----> 3 plot_bboxes(image, results[0].boxes.boxes, score=True, conf=0.5)
#
# NameError: name 'plot_bboxes' is not defined

# %%
# !yolo task=segment mode=predict model=yolov8x-seg.pt conf=0.5 source={paths1[0]}
# Out:
# ...
#
#   0%|          | 0.00/137M [00:00<?, ?B/s]

# %%
paths_sp=[]
for dirname, _, filenames in os.walk('D:/hm/Projoects/yolo8/Storage_temp/Data/Image/TM_Leak/MRCNN/sample1/'):
    for filename in filenames:
        if filename[-4:]=='.jpg':
            paths_sp+=[(os.path.join(dirname, filename))]
image = Image.open(paths_sp[0])
image=np.array(image)
plt.figure(figsize=(16,8))
plt.imshow(image)
plt.show()
# Out:
#   0%|          | 24.0k/137M [00:01<2:01:19, 19.8kB/s]
#   1%|          | 1.27M/137M [00:01<01:51, 1.28MB/s]
#   2%|2         | 3.30M/137M [00:01<00:37, 3.70MB/s]
#   3%|3         | 4.46M/137M [00:02<00:44, 3.10MB/s]
#   4%|3         | 5.26M/137M [00:02<00:48, 2.86MB/s]
#   4%|4         | 5.85M/137M [00:02<00:50, 2.75MB/s]
#   5%|4         | 6.32M/137M [00:02<00:51, 2.67MB/s]
#   5%|4         | 6.71M/137M [00:03<00:54, 2.52MB/s]
#   5%|5         | 7.04M/137M [00:03<00:52, 2.59MB/s]
#   5%|5         | 7.36M/137M [00:03<00:53, 2.53MB/s]
#   6%|5         | 7.65M/137M [00:03<00:54, 2.52MB/s]
#   6%|5         | 7.92M/137M [00:03<00:55, 2.47MB/s]
#   6%|5         | 8.18M/137M [00:03<00:55, 2.46MB/s]
#   6%|6         | 8.43M/137M [00:03<00:55, 2.45MB/s]
#   6%|6         | 8.67M/137M [00:03<00:55, 2.41MB/s]
#   6%|6         | 8.91M/137M [00:03<00:55, 2.42MB/s]
#   7%|6         | 9.16M/137M [00:04<00:56, 2.39MB/s]
#   7%|6         | 9.39M/137M [00:04<00:56, 2.38MB/s]
# ...
